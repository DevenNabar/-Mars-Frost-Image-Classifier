# %% [markdown]
# <h1>DSCI552 FINAL PROJECT</h1>
# <p>NAME: DEVEN PARAG NABAR<br>
# USERNAME: DEVENNABAR<br>
# USCID: 7229446568</p>

# %%
import os
from pathlib import Path
import logging
import numpy as np
import random
import tensorflow as tf
from PIL import Image
import random
import tensorflow as tf
import matplotlib.pyplot as plt
from tensorflow import keras
from sklearn.metrics import classification_report
from keras.models import Sequential, load_model
from keras.layers import Input, Dense, Conv2D, Flatten, Dropout, MaxPooling2D, BatchNormalization, Activation
from keras.optimizers import Adam
from keras.losses import SparseCategoricalCrossentropy, BinaryCrossentropy
from keras.callbacks import EarlyStopping
from keras import regularizers
from keras.layers.experimental.preprocessing import RandomCrop, RandomFlip, RandomRotation, RandomZoom, RandomContrast, RandomTranslation
import warnings
warnings.filterwarnings("ignore")
tf.config.list_physical_devices('GPU')
# Out:
# [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !wget https://www.dropbox.com/sh/38zygdpo6u7alwy/AAB1PJuhqF-58GZJ-oD4xl5Ya?dl=0
# Out:
# --2023-12-11 02:59:10--  https://www.dropbox.com/sh/38zygdpo6u7alwy/AAB1PJuhqF-58GZJ-oD4xl5Ya?dl=0
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.83.18, 2620:100:6018:18::a27d:312
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.83.18|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: /sh/raw/38zygdpo6u7alwy/AAB1PJuhqF-58GZJ-oD4xl5Ya [following]
# --2023-12-11 02:59:11--  https://www.dropbox.com/sh/raw/38zygdpo6u7alwy/AAB1PJuhqF-58GZJ-oD4xl5Ya
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucaa557dd244566eb0b0857ed9a4.dl.dropboxusercontent.com/zip_download_get/BsnsTaGh4gdoDR2FXLIUgIUgG1pFb67xPGZ3B5M3j1TbnaHt4Fl7kakrf6hDHuyVrdts0MS9xR03uiFpB36wtTNBTb4aMBdqeuOmCA05MhGjxA# [following]
# --2023-12-11 02:59:12--  https://ucaa557dd244566eb0b0857ed9a4.dl.dropboxusercontent.com/zip_download_get/BsnsTaGh4gdoDR2FXLIUgIUgG1pFb67xPGZ3B5M3j1TbnaHt4Fl7kakrf6hDHuyVrdts0MS9xR03uiFpB36wtTNBTb4aMBdqeuOmCA05MhGjxA
# Resolving ucaa557dd244566eb0b0857ed9a4.dl.dropboxusercontent.com (ucaa557dd244566eb0b0857ed9a4.dl.dropboxusercontent.com)... 162.125.3.15, 2620:100:6018:15::a27d:30f
# Connecting to ucaa557dd244566eb0b0857ed9a4.dl.dropboxusercontent.com (ucaa557dd244566eb0b0857ed9a4.dl.dropboxusercontent.com)|162.125.3.15|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2738462210 (2.5G) [application/zip]
# Saving to: ‘AAB1PJuhqF-58GZJ-oD4xl5Ya?dl=0’
#
# AAB1PJuhqF-58GZJ-oD 100%[===================>]   2.55G  89.3MB/s    in 30s
#
# 2023-12-11 02:59:42 (86.7 MB/s) - ‘AAB1PJuhqF-58GZJ-oD4xl5Ya?dl=0’ saved [2738462210/2738462210]

# %%
import zipfile
with zipfile.ZipFile("/content/AAB1PJuhqF-58GZJ-oD4xl5Ya?dl=0","r") as zip_ref:
    zip_ref.extractall("data")

with zipfile.ZipFile("/content/data/data.zip","r") as zip_ref:
    zip_ref.extractall("data")

# %%
import os
import os.path as op
import json
from pathlib import Path
import shutil
import logging
import numpy as np
from tqdm import tqdm
from skimage import io

# Logging configuration
logging.basicConfig(level=logging.INFO,
                    datefmt='%H:%M:%S',
                    format='%(asctime)s | %(levelname)-5s | %(module)-15s | %(message)s')

IMAGE_SIZE = (299, 299)  # All images contained in this dataset are 299x299 (originally, to match Inception v3 input size)
SEED = 17

# Head directory containing all image subframes
data_head_dir = Path('./data/data')
# data_head_dir = Path('./drive/MyDrive/data')


# Find all subframe directories
subdirs = [Path(subdir.stem) for subdir in data_head_dir.iterdir() if subdir.is_dir()]
src_image_ids = ['_'.join(a_path.name.split('_')[:3]) for a_path in subdirs]

# %%
# Load train/val/test subframe IDs
def load_text_ids(file_path):
    """Simple helper to load all lines from a text file"""
    with open(file_path, 'r') as f:
        lines = [line.strip() for line in f.readlines()]
        # print(lines)
    return lines

# Load the subframe names for the three data subsets
train_ids = load_text_ids('/content/drive/MyDrive/train_source_images.txt')
validate_ids = load_text_ids('/content/drive/MyDrive/val_source_images.txt')
test_ids = load_text_ids('/content/drive/MyDrive/test_source_images.txt')
# train_ids = load_text_ids('test_source_images.txt')
# validate_ids = load_text_ids('val_source_images.txt')
# test_ids = load_text_ids('test_source_images.txt')

# Generate a list containing the dataset split for the matching subdirectory names
subdir_splits = []
for src_id in src_image_ids:
    if src_id in train_ids:
        subdir_splits.append('train')
    elif src_id in validate_ids:
        subdir_splits.append('validate')
    elif(src_id in test_ids):
        subdir_splits.append('test')
    else:
        logging.warning(f'{src_id}: Did not find designated split in train/validate/test list.')
        subdir_splits.append(None)

# %%
# function taken from Piazza
def load_and_preprocess(img_loc, label):

    def _inner_function(img_loc, label):
        # Convert tensor to native type
        img_loc_str = img_loc.numpy().decode('utf-8')

        # Load image using PIL and convert to RGB
        img = Image.open(img_loc_str).convert('RGB')

        # Convert PIL image to numpy array
        img = np.array(img)
        img = tf.image.resize(img, [299, 299])

        # Normalize the image to the [0, 1] range
        img = img / 255.0

        # Convert label to integer (assuming binary classification)
        label = 1 if label.numpy().decode('utf-8') == 'frost' else 0

        return img, label

    # Wrap the Python function
    X, y = tf.py_function(_inner_function, [img_loc, label], [tf.float32, tf.int64])

    # Set the shape of the tensors
    X.set_shape([299, 299, 3])
    y.set_shape([])

    return X, y

def load_subdir_data(dir_path, image_size, seed=None):

    """Helper to create a TF dataset from each image subdirectory"""

    # Grab only the classes that (1) we want to keep and (2) exist in this directory
    tile_dir = dir_path / Path('tiles')
    label_dir = dir_path /Path('labels')

    loc_list = []

    for folder in os.listdir(tile_dir):
        if os.path.isdir(os.path.join(tile_dir, folder)):
            for file in os.listdir(os.path.join(tile_dir, folder)):
                if file.endswith(".png"):
                    loc_list.append((os.path.join(os.path.join(tile_dir, folder), file), folder))

    return loc_list

# Loop over all subframes, loading each into a list
tf_data_train, tf_data_test, tf_data_val = [], [], []
tf_dataset_train, tf_dataset_test, tf_dataset_val = [], [], []

# Update the batch and buffer size as per your model requirements
buffer_size = 128
batch_size = 64

for subdir, split in zip(subdirs, subdir_splits):
    full_path = data_head_dir / subdir
    if split=='validate':
        tf_data_val.extend(load_subdir_data(full_path, IMAGE_SIZE, SEED))
    elif split=='train':
        tf_data_train.extend(load_subdir_data(full_path, IMAGE_SIZE, SEED))
    elif split=='test':
        tf_data_test.extend(load_subdir_data(full_path, IMAGE_SIZE, SEED))

random.shuffle(tf_data_train)
img_list, label_list = zip(*tf_data_train)
img_list_t = tf.convert_to_tensor(img_list)
lb_list_t = tf.convert_to_tensor(label_list)

tf_dataset_train = tf.data.Dataset.from_tensor_slices((img_list_t, lb_list_t))
tf_dataset_train = tf_dataset_train.map(load_and_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
tf_dataset_train = tf_dataset_train.shuffle(buffer_size=buffer_size).batch(batch_size)

random.shuffle(tf_data_val)
img_list, label_list = zip(*tf_data_val)
img_list_t = tf.convert_to_tensor(img_list)
lb_list_t = tf.convert_to_tensor(label_list)

tf_dataset_val = tf.data.Dataset.from_tensor_slices((img_list_t, lb_list_t))
tf_dataset_val = tf_dataset_val.map(load_and_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
tf_dataset_val = tf_dataset_val.shuffle(buffer_size=buffer_size).batch(batch_size)

random.shuffle(tf_data_test)
img_list, label_list = zip(*tf_data_test)
img_list_t = tf.convert_to_tensor(img_list)
lb_list_t = tf.convert_to_tensor(label_list)

tf_dataset_test = tf.data.Dataset.from_tensor_slices((img_list_t, lb_list_t))
tf_dataset_test = tf_dataset_test.map(load_and_preprocess, num_parallel_calls=tf.data.experimental.AUTOTUNE)
tf_dataset_test = tf_dataset_test.shuffle(buffer_size=buffer_size).batch(batch_size)

# %%
# All Data Augmentation Layers mentioned in the project document
data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.2),
    RandomZoom(0.2),
    RandomTranslation(height_factor=0.2, width_factor=0.2),
    RandomContrast(factor=0.2),
    RandomCrop(height=299, width=299)
])

# %%
model = Sequential()
model.add(Input(shape=(299, 299, 3)))
model.add(data_augmentation)
model.add(Conv2D(16, (3, 3), kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(32, (3, 3), kernel_regularizer=regularizers.l2(0.001)))
# model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Conv2D(64, (3, 3), kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(MaxPooling2D((2, 2)))
model.add(Dropout(0.3))
model.add(Flatten())
model.add(Dense(64, kernel_regularizer=regularizers.l2(0.001)))
model.add(BatchNormalization())
model.add(Activation('relu'))
model.add(Dropout(0.3))
model.add(Dense(1, activation='sigmoid')) # used sigmoid instead of softmax because it was performing better

model.compile(optimizer=Adam(learning_rate=0.001),
                loss=BinaryCrossentropy(from_logits=True),
                metrics=['accuracy'])
model.summary()
# Out:
# Model: "sequential_1"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  sequential (Sequential)     (None, 299, 299, 3)       0
#
#  conv2d (Conv2D)             (None, 297, 297, 16)      448
#
#  batch_normalization (Batch  (None, 297, 297, 16)      64
#  Normalization)
#
#  activation (Activation)     (None, 297, 297, 16)      0
#
#  max_pooling2d (MaxPooling2  (None, 148, 148, 16)      0
#  D)
#
#  dropout (Dropout)           (None, 148, 148, 16)      0
#
#  conv2d_1 (Conv2D)           (None, 146, 146, 32)      4640
#
#  activation_1 (Activation)   (None, 146, 146, 32)      0
#
#  max_pooling2d_1 (MaxPoolin  (None, 73, 73, 32)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 73, 73, 32)        0
#
#  conv2d_2 (Conv2D)           (None, 71, 71, 64)        18496
#
#  batch_normalization_1 (Bat  (None, 71, 71, 64)        256
#  chNormalization)
#
#  activation_2 (Activation)   (None, 71, 71, 64)        0
#
#  max_pooling2d_2 (MaxPoolin  (None, 35, 35, 64)        0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 35, 35, 64)        0
#
#  flatten (Flatten)           (None, 78400)             0
#
#  dense (Dense)               (None, 64)                5017664
#
#  batch_normalization_2 (Bat  (None, 64)                256
#  chNormalization)
#
#  activation_3 (Activation)   (None, 64)                0
#
#  dropout_3 (Dropout)         (None, 64)                0
#
#  dense_1 (Dense)             (None, 1)                 65
#
# =================================================================
# Total params: 5041889 (19.23 MB)
# Trainable params: 5041601 (19.23 MB)
# Non-trainable params: 288 (1.12 KB)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=5, restore_best_weights=True)
history = model.fit(tf_dataset_train, epochs=20, verbose=1, validation_data=tf_dataset_val, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 464/464 [==============================] - 373s 759ms/step - loss: 0.7807 - accuracy: 0.6929 - val_loss: 0.4850 - val_accuracy: 0.8979
# Epoch 2/20
# 464/464 [==============================] - 311s 670ms/step - loss: 0.6097 - accuracy: 0.7557 - val_loss: 3.3232 - val_accuracy: 0.3220
# Epoch 3/20
# 464/464 [==============================] - 299s 644ms/step - loss: 0.5813 - accuracy: 0.7809 - val_loss: 0.6965 - val_accuracy: 0.6995
# Epoch 4/20
# 464/464 [==============================] - 297s 639ms/step - loss: 0.5784 - accuracy: 0.7987 - val_loss: 1.4930 - val_accuracy: 0.4713
# Epoch 5/20
# 464/464 [==============================] - 297s 638ms/step - loss: 0.5671 - accuracy: 0.8285 - val_loss: 0.7549 - val_accuracy: 0.6413
# Epoch 6/20
# 464/464 [==============================] - 298s 642ms/step - loss: 0.5810 - accuracy: 0.8306 - val_loss: 0.5816 - val_accuracy: 0.8192

# %%
test_loss,test_accuracy = model.evaluate(tf_dataset_test)
print("test accuracy - ",test_accuracy*100, "%")
# Out:
# 201/201 [==============================] - 92s 454ms/step - loss: 0.9436 - accuracy: 0.4978
# test accuracy -  49.777743220329285 %

# %%
import matplotlib.pyplot as plt

def plot_loss(history):
    plt.plot(history.history['loss'], label='Training Loss')
    plt.plot(history.history['val_loss'], label='Validation Loss')
    plt.xlabel('Epochs')
    plt.ylabel('Loss')
    plt.legend()
    plt.show()

# Example usage:
# Assuming you have a variable named 'history' that contains the training history.
# plot_loss(history)

# %%
plot_loss(history)

# %%
import matplotlib.pyplot as plt

def plot_accuracy(history):
    plt.plot(history.history['accuracy'], label='Training Accuracy')
    plt.plot(history.history['val_accuracy'], label='Validation Accuracy')
    plt.xlabel('Epochs')
    plt.ylabel('Accuracy')
    plt.legend()
    plt.show()

# Example usage:
# Assuming you have a variable named 'history' that contains the training history.
# plot_accuracy(history)

# %%
plot_accuracy(history)

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score, roc_curve, auc, accuracy_score, ConfusionMatrixDisplay
import seaborn as sns
from yellowbrick.classifier import ClassificationReport



def eval_model(model, tf_data):
    y_true = []
    y_pred = []
    for batch_data, batch_label in tf_data:
        preds = model.predict(batch_data)
        # print(preds)
        # print(batch_label)
        y_true.extend(batch_label.numpy().astype(int))
        y_pred.extend(np.argmax(preds, axis=1).astype(int))
    # print(y_pred)
    # print("##")
    # print(y_true)
    print("confusion_matrix")
    conf_matrix = confusion_matrix(y_true, y_pred)
    plt.figure(figsize=(8, 6))
    sns.heatmap(conf_matrix, annot=True, fmt='d', cmap='Blues',
                xticklabels=['Non-Frost', 'Frost'], yticklabels=['Non-Frost', 'Frost'])
    plt.title('Confusion Matrix')
    plt.xlabel('Predicted Label')
    plt.ylabel('True Label')
    plt.show()

    print("classification report")
    print(classification_report(y_true, y_pred))

print("Evaluation for CNN")
eval_model(model, tf_dataset_test)
# Out:
# Evaluation for CNN
# 2/2 [==============================] - 1s 18ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 73ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 67ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 19ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 58ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 98ms/step
# 2/2 [==============================] - 0s 88ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 77ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 91ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 44ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 64ms/step
# 2/2 [==============================] - 0s 62ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 78ms/step
# 2/2 [==============================] - 0s 66ms/step
# 2/2 [==============================] - 0s 57ms/step
# 2/2 [==============================] - 0s 75ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 54ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 21ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 18ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 20ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 50ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 103ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 59ms/step
# 2/2 [==============================] - 0s 23ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 96ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 63ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 61ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 22ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 60ms/step
# 2/2 [==============================] - 0s 74ms/step
# 2/2 [==============================] - 0s 35ms/step
# 2/2 [==============================] - 0s 43ms/step
# 2/2 [==============================] - 0s 32ms/step
# 1/1 [==============================] - 1s 1s/step
# confusion_matrix
# classification report
#               precision    recall  f1-score   support
#
#            0       0.34      1.00      0.51      4418
#            1       0.00      0.00      0.00      8405
#
#     accuracy                           0.34     12823
#    macro avg       0.17      0.50      0.26     12823
# weighted avg       0.12      0.34      0.18     12823

# %%
import numpy as np
import pandas as pd
import tensorflow as tf
import os
import cv2
import warnings
warnings.filterwarnings('ignore')
from random import sample
import math
import matplotlib.pyplot as plt
from tensorflow import keras
from keras.layers import Input, Lambda, Dense, Flatten,Dropout,BatchNormalization,Activation
from keras.models import Model
from keras.applications.vgg16 import VGG16
from keras.applications import ResNet50
from keras.applications.vgg16 import preprocess_input
from keras.preprocessing import image
from keras.preprocessing.image import ImageDataGenerator
from keras.models import Sequential
from keras.callbacks import EarlyStopping
from keras.applications import EfficientNetB0
from keras.preprocessing.image import ImageDataGenerator
from keras.metrics import Precision, Recall
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import ConfusionMatrixDisplay

# %%
from keras.applications import ResNet50
from keras.models import Sequential, Model
from keras.layers import Input, Flatten, Dense, BatchNormalization, Dropout
from keras.optimizers import Adam
from keras.losses import BinaryCrossentropy
from keras.layers.experimental.preprocessing import RandomFlip, RandomRotation, RandomZoom, RandomTranslation, RandomContrast, RandomCrop

def build_resnet_model(input_shape=(299, 299, 3)):
    # Define data augmentation layer
    data_augmentation = Sequential([
    RandomFlip("horizontal_and_vertical"),
    RandomRotation(0.2),
    RandomZoom(0.2),
    RandomTranslation(height_factor=0.2, width_factor=0.2),
    RandomContrast(factor=0.2),
    RandomCrop(height=299, width=299)
])

    # Base ResNet50 model
    base_model = ResNet50(include_top=False, weights='imagenet', input_shape=input_shape)
    base_model.trainable = False

    # Build the custom model
    inputs = Input(shape=input_shape)
    augmented_inputs = data_augmentation(inputs)
    features = base_model(augmented_inputs)
    flattened_features = Flatten()(features)
    normalized_features = BatchNormalization()(flattened_features)
    dropout1 = Dropout(0.2)(normalized_features)
    dense1 = Dense(1024, activation='relu')(dropout1)
    normalized_dense1 = BatchNormalization()(dense1)
    dropout2 = Dropout(0.2)(normalized_dense1)
    output = Dense(1, activation='sigmoid')(dropout2)

    model = Model(inputs=inputs, outputs=output)

    # Compile the model
    model.compile(optimizer=Adam(learning_rate=0.001),
                  loss=BinaryCrossentropy(from_logits=True),
                  metrics=['accuracy'])

    return model

# Build the ResNet model
resnet_model = build_resnet_model()

# Display the model summary
resnet_model.summary()
# Out:
# Model: "model_2"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_7 (InputLayer)        [(None, 299, 299, 3)]     0
#
#  sequential_4 (Sequential)   (None, 299, 299, 3)       0
#
#  resnet50 (Functional)       (None, 10, 10, 2048)      23587712
#
#  flatten_3 (Flatten)         (None, 204800)            0
#
#  batch_normalization_7 (Bat  (None, 204800)            819200
#  chNormalization)
#
#  dropout_8 (Dropout)         (None, 204800)            0
#
#  dense_6 (Dense)             (None, 1024)              209716224
#
#  batch_normalization_8 (Bat  (None, 1024)              4096
#  chNormalization)
#
#  dropout_9 (Dropout)         (None, 1024)              0
#
#  dense_7 (Dense)             (None, 1)                 1025
#
# =================================================================
# Total params: 234128257 (893.13 MB)
# Trainable params: 210128897 (801.58 MB)
# Non-trainable params: 23999360 (91.55 MB)
# _________________________________________________________________

# %%
early_stopping = EarlyStopping(monitor='val_loss', patience=10, restore_best_weights=True)
history = resnet_model.fit(tf_dataset_train, epochs=20, verbose=1, validation_data=tf_dataset_val, callbacks=[early_stopping])
# Out:
# Epoch 1/20
# 464/464 [==============================] - 501s 1s/step - loss: 0.6182 - accuracy: 0.7527 - val_loss: 0.7046 - val_accuracy: 0.6424
# Epoch 2/20
# 464/464 [==============================] - 449s 967ms/step - loss: 0.4457 - accuracy: 0.7948 - val_loss: 0.8762 - val_accuracy: 0.5610
# Epoch 3/20
# 464/464 [==============================] - 445s 958ms/step - loss: 0.4248 - accuracy: 0.8057 - val_loss: 0.8752 - val_accuracy: 0.5890
# Epoch 4/20
# 464/464 [==============================] - 446s 961ms/step - loss: 0.4127 - accuracy: 0.8129 - val_loss: 0.8915 - val_accuracy: 0.5362
# Epoch 5/20
# 464/464 [==============================] - 450s 968ms/step - loss: 0.4039 - accuracy: 0.8187 - val_loss: 0.8516 - val_accuracy: 0.5720
# Epoch 6/20
# 464/464 [==============================] - 447s 962ms/step - loss: 0.4169 - accuracy: 0.8102 - val_loss: 0.9399 - val_accuracy: 0.5412
# Epoch 7/20
# 464/464 [==============================] - 446s 961ms/step - loss: 0.4092 - accuracy: 0.8123 - val_loss: 0.8422 - val_accuracy: 0.5785
# Epoch 8/20
# 464/464 [==============================] - 445s 959ms/step - loss: 0.4055 - accuracy: 0.8140 - val_loss: 0.7983 - val_accuracy: 0.6012
# Epoch 9/20
# 464/464 [==============================] - 445s 958ms/step - loss: 0.4034 - accuracy: 0.8165 - val_loss: 1.0419 - val_accuracy: 0.5409
# Epoch 10/20
# 464/464 [==============================] - 444s 956ms/step - loss: 0.3930 - accuracy: 0.8228 - val_loss: 0.7509 - val_accuracy: 0.6762
# Epoch 11/20
# 464/464 [==============================] - 475s 1s/step - loss: 0.3913 - accuracy: 0.8229 - val_loss: 1.2950 - val_accuracy: 0.4798

# %%
test_loss1,test_accuracy1 = resnet_model.evaluate(tf_dataset_test)
print("test accuracy - ",test_accuracy1*100, "%")
# Out:
# 201/201 [==============================] - 130s 645ms/step - loss: 0.4739 - accuracy: 0.7800
# test accuracy -  78.00046801567078 %

# %%
plot_accuracy(history)

# %%
plot_loss(history)

# %%
print("Evaluation for ResNet")
eval_model(resnet_model, tf_dataset_test)
# Out:
# Evaluation for ResNet
# 2/2 [==============================] - 4s 35ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 0s 304ms/step
# 2/2 [==============================] - 0s 87ms/step
# 2/2 [==============================] - 0s 262ms/step
# 2/2 [==============================] - 0s 273ms/step
# 2/2 [==============================] - 0s 210ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 168ms/step
# 2/2 [==============================] - 0s 171ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 321ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 65ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 268ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 198ms/step
# 2/2 [==============================] - 0s 216ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 1s 191ms/step
# 2/2 [==============================] - 0s 309ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 1s 330ms/step
# 2/2 [==============================] - 0s 280ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 36ms/step
# 2/2 [==============================] - 0s 125ms/step
# 2/2 [==============================] - 0s 270ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 318ms/step
# 2/2 [==============================] - 0s 42ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 317ms/step
# 2/2 [==============================] - 0s 205ms/step
# 2/2 [==============================] - 0s 328ms/step
# 2/2 [==============================] - 1s 354ms/step
# 2/2 [==============================] - 0s 331ms/step
# 2/2 [==============================] - 0s 71ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 252ms/step
# 2/2 [==============================] - 0s 324ms/step
# 2/2 [==============================] - 0s 328ms/step
# 2/2 [==============================] - 0s 273ms/step
# 2/2 [==============================] - 0s 241ms/step
# 2/2 [==============================] - 0s 169ms/step
# 2/2 [==============================] - 0s 166ms/step
# 2/2 [==============================] - 0s 119ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 46ms/step
# 2/2 [==============================] - 0s 228ms/step
# 2/2 [==============================] - 0s 90ms/step
# 2/2 [==============================] - 0s 322ms/step
# 2/2 [==============================] - 0s 228ms/step
# 2/2 [==============================] - 1s 193ms/step
# 2/2 [==============================] - 0s 338ms/step
# 2/2 [==============================] - 1s 203ms/step
# 2/2 [==============================] - 0s 183ms/step
# 2/2 [==============================] - 0s 334ms/step
# 2/2 [==============================] - 0s 206ms/step
# 2/2 [==============================] - 0s 327ms/step
# 2/2 [==============================] - 0s 72ms/step
# 2/2 [==============================] - 0s 85ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 326ms/step
# 2/2 [==============================] - 0s 301ms/step
# 2/2 [==============================] - 0s 320ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 47ms/step
# 2/2 [==============================] - 0s 147ms/step
# 2/2 [==============================] - 0s 160ms/step
# 2/2 [==============================] - 0s 315ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 1s 186ms/step
# 2/2 [==============================] - 0s 271ms/step
# 2/2 [==============================] - 1s 202ms/step
# 2/2 [==============================] - 0s 283ms/step
# 2/2 [==============================] - 1s 195ms/step
# 2/2 [==============================] - 1s 253ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 331ms/step
# 2/2 [==============================] - 0s 341ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 0s 276ms/step
# 2/2 [==============================] - 0s 326ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 49ms/step
# 2/2 [==============================] - 0s 109ms/step
# 2/2 [==============================] - 0s 106ms/step
# 2/2 [==============================] - 0s 341ms/step
# 2/2 [==============================] - 0s 27ms/step
# 2/2 [==============================] - 0s 26ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 328ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 29ms/step
# 2/2 [==============================] - 0s 191ms/step
# 2/2 [==============================] - 1s 205ms/step
# 2/2 [==============================] - 0s 329ms/step
# 2/2 [==============================] - 1s 186ms/step
# 2/2 [==============================] - 0s 32ms/step
# 2/2 [==============================] - 0s 39ms/step
# 2/2 [==============================] - 0s 196ms/step
# 2/2 [==============================] - 1s 281ms/step
# 2/2 [==============================] - 0s 186ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 324ms/step
# 2/2 [==============================] - 0s 176ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 322ms/step
# 2/2 [==============================] - 0s 261ms/step
# 2/2 [==============================] - 0s 177ms/step
# 2/2 [==============================] - 0s 317ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 325ms/step
# 2/2 [==============================] - 0s 328ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 146ms/step
# 2/2 [==============================] - 0s 195ms/step
# 2/2 [==============================] - 0s 45ms/step
# 2/2 [==============================] - 0s 346ms/step
# 2/2 [==============================] - 0s 239ms/step
# 2/2 [==============================] - 1s 275ms/step
# 2/2 [==============================] - 0s 326ms/step
# 2/2 [==============================] - 0s 199ms/step
# 2/2 [==============================] - 0s 193ms/step
# 2/2 [==============================] - 0s 34ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 326ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 172ms/step
# 2/2 [==============================] - 0s 93ms/step
# 2/2 [==============================] - 0s 336ms/step
# 2/2 [==============================] - 0s 25ms/step
# 2/2 [==============================] - 0s 280ms/step
# 2/2 [==============================] - 0s 178ms/step
# 2/2 [==============================] - 0s 326ms/step
# 2/2 [==============================] - 0s 184ms/step
# 2/2 [==============================] - 0s 33ms/step
# 2/2 [==============================] - 0s 149ms/step
# 2/2 [==============================] - 1s 228ms/step
# 2/2 [==============================] - 1s 218ms/step
# 2/2 [==============================] - 0s 290ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 40ms/step
# 2/2 [==============================] - 0s 110ms/step
# 2/2 [==============================] - 0s 53ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 240ms/step
# 2/2 [==============================] - 0s 31ms/step
# 2/2 [==============================] - 0s 179ms/step
# 2/2 [==============================] - 0s 187ms/step
# 2/2 [==============================] - 0s 289ms/step
# 2/2 [==============================] - 0s 327ms/step
# 2/2 [==============================] - 0s 216ms/step
# 2/2 [==============================] - 0s 233ms/step
# 2/2 [==============================] - 0s 326ms/step
# 2/2 [==============================] - 0s 285ms/step
# 2/2 [==============================] - 0s 208ms/step
# 2/2 [==============================] - 0s 181ms/step
# 2/2 [==============================] - 0s 37ms/step
# 2/2 [==============================] - 0s 48ms/step
# 2/2 [==============================] - 0s 314ms/step
# 2/2 [==============================] - 0s 38ms/step
# 2/2 [==============================] - 0s 202ms/step
# 2/2 [==============================] - 0s 253ms/step
# 2/2 [==============================] - 0s 97ms/step
# 2/2 [==============================] - 0s 185ms/step
# 2/2 [==============================] - 0s 190ms/step
# 2/2 [==============================] - 0s 68ms/step
# 2/2 [==============================] - 0s 320ms/step
# 2/2 [==============================] - 0s 24ms/step
# 2/2 [==============================] - 0s 102ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 28ms/step
# 2/2 [==============================] - 0s 196ms/step
# 2/2 [==============================] - 0s 180ms/step
# 2/2 [==============================] - 0s 170ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 174ms/step
# 2/2 [==============================] - 0s 243ms/step
# 2/2 [==============================] - 0s 30ms/step
# 2/2 [==============================] - 0s 55ms/step
# 2/2 [==============================] - 1s 362ms/step
# 2/2 [==============================] - 0s 41ms/step
# 2/2 [==============================] - 1s 353ms/step
# 2/2 [==============================] - 0s 182ms/step
# 2/2 [==============================] - 0s 175ms/step
# 2/2 [==============================] - 0s 175ms/step
# 1/1 [==============================] - 3s 3s/step
# confusion_matrix
# classification report
#               precision    recall  f1-score   support
#
#            0       0.34      1.00      0.51      4418
#            1       0.00      0.00      0.00      8405
#
#     accuracy                           0.34     12823
#    macro avg       0.17      0.50      0.26     12823
# weighted avg       0.12      0.34      0.18     12823
